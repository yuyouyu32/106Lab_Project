# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('result.csv')
test
# Out:
#         sinx      cosx  prediction
# 0   0.452026  0.892005    1.344027
# 1   0.994827  0.101586    1.096409
# 2   0.622989 -0.782231   -0.159242
# 3  -0.321622 -0.946868   -1.268487
# 4  -0.970535 -0.240959   -1.211491
# 5  -0.727143  0.686487   -0.040656
# 6   0.184782  0.982780    1.167558
# 7   0.926819  0.375510    1.302324
# 8   0.816743 -0.577002    0.239740
# 9  -0.044243 -0.999021   -1.043260
# 10 -0.864551 -0.502544   -1.367092
# 11 -0.889996  0.455969   -0.434025
# 12 -0.097182  0.995267    0.898082
# 13  0.784980  0.619521    1.404497
# 14  0.945435 -0.325810    0.619624
# 15  0.236661 -0.971592   -0.734929
# 16 -0.689698 -0.724097   -1.413791
# 17 -0.981952  0.189129   -0.792820
# 18 -0.371404  0.928471    0.557066
# 19  0.580611  0.814181    1.394788

# %%
for index, row in test.iterrows():
    print(row['cosx'])
    print(row.keys())
    print(row.values)
    break
# Out:
# 0.89200487
# Index(['sinx', 'cosx', 'prediction'], dtype='object')
# [0.45202579 0.89200487 1.34402651]

# %%
from utils import _add_info_xml
_add_info_xml(picture_names=['result.jpg','aic_or_bic.jpg'], result=test)
